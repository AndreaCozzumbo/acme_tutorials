# %% [markdown]
# # Including sky localization

# %% [markdown]
# Before starting, let's first familiarize with sky localization maps:
#
# https://samueleronchini.github.io/acme_tutorials/alerts/skymaps.html

# %% [markdown]
# ## Spatio-temporal joint FAR

# %%
from astropy.table import QTable
from ligo.raven import gracedb_events, search

skymap_grb = QTable.read('./754189311_0_n_PROBMAP.fits')

skymap_gw = QTable.read('./Bilby.multiorder.fits')

tl, th = -10, 20
se_far = 9.503e-10  # Hz
far_ext = 1 / 44 / 60  # 1/44 min

far_joint = search.coinc_far(se_far, tl, th,
                far_ext = far_ext,
                joint_far_method = 'targeted', # 'targeted' or 'untargeted'
                ext_search = 'SubGRBTargeted', # "GRB", "SubGRB", "SubGRBTargeted", "MDC", or "HEN" --> if you don't specify joint_far_method, you must specify ext_search
                # {'GRB', 'SubGRB', 'HEN'} --> uses untargeted
                # {'SubGRBTargeted'} --> uses targeted
                ext_pipeline = 'Swift', # --> if you don't specify far_ext_thresh, you must specify ext_pipeline
                gw_skymap=skymap_gw,
                ext_skymap=skymap_grb)

# %% [markdown]
# ## Sky overlap integral

# %%
sky_overlap = search.skymap_overlap_integral(skymap_gw, ext_skymap=skymap_grb)

# %% [markdown]
# :::{note}
# If both maps are multi-order, then both maps are internally upsampled to the highest HEALPix depth present among the two. If only the external map if flat, for each pixel of the MOC GW map the corrisponding prob density of the external map is computed in the same position. If both flat, a simple element-wise multiplication is done.
# :::

# %% [markdown]
# ## Sky overlap integral for external precise localization

# %%
gw_map, _ = ligo.skymap.io.fits.read_sky_map('Bilby.multiorder.fits', nest=True)
sky_overlap_point = search.skymap_overlap_integral(gw_map,
                            ra=90, dec=30) 
# use the gw map in flat format. The functions seems to not handle MOC skymaps when using ext rea and dec 
sky_overlap_point
# Out:
# np.float64(1.4768264524886637e-84)

# %% [markdown]
# ## Combining sky maps

# %% [markdown]
# The function used here for two MOC maps is taken from
# https://rtd.igwn.org/projects/gwcelery/en/latest/_modules/gwcelery/tasks/external_skymaps.html#combine_skymaps_moc_moc

# %%
from hpmoc import PartialUniqSkymap
from hpmoc.utils import reraster, uniq_intersection
from ligo.skymap.distance import parameters_to_marginal_moments
import numpy as np

def combine_skymaps_moc_moc(gw_sky, ext_sky):
    """This function combines a multi-ordered (MOC) GW sky map with a MOC
    external skymap.
    """
    gw_sky_hpmoc = PartialUniqSkymap(gw_sky["PROBDENSITY"], gw_sky["UNIQ"],
                                     name="PROBDENSITY", meta=gw_sky.meta)
    # Determine the column name in ext_sky and rename it as PROBDENSITY.
    ext_sky_hpmoc = PartialUniqSkymap(ext_sky["PROBDENSITY"], ext_sky["UNIQ"],
                                      name="PROBDENSITY", meta=ext_sky.meta)

    comb_sky_hpmoc = gw_sky_hpmoc * ext_sky_hpmoc
    comb_sky_hpmoc /= np.sum(comb_sky_hpmoc.s * comb_sky_hpmoc.area())
    comb_sky = comb_sky_hpmoc.to_table(name='PROBDENSITY')

    if 'DISTMU' in gw_sky.keys() and 'DISTSIGMA' in gw_sky.keys():
        UNIQ = comb_sky['UNIQ']
        UNIQ_ORIG = gw_sky['UNIQ']
        intersection = uniq_intersection(UNIQ_ORIG, UNIQ)
        DIST_MU = reraster(UNIQ_ORIG,
                           gw_sky["DISTMU"],
                           UNIQ,
                           method='copy',
                           intersection=intersection)
        DIST_SIGMA = reraster(UNIQ_ORIG,
                              gw_sky["DISTSIGMA"],
                              UNIQ,
                              method='copy',
                              intersection=intersection)
        DIST_NORM = reraster(UNIQ_ORIG,
                             gw_sky["DISTNORM"],
                             UNIQ,
                             method='copy',
                             intersection=intersection)
        comb_sky.add_columns([DIST_MU, DIST_SIGMA, DIST_NORM],
                             names=['DISTMU', 'DISTSIGMA', 'DISTNORM'])

        distmean, diststd = parameters_to_marginal_moments(
            comb_sky['PROBDENSITY'] * comb_sky_hpmoc.area().value,
            comb_sky['DISTMU'], comb_sky['DISTSIGMA'])
        comb_sky.meta['distmean'], comb_sky.meta['diststd'] = distmean, diststd

    if 'ORDERING' in comb_sky.meta:
        del comb_sky.meta['ORDERING']
    return comb_sky

# %% [markdown]
# If your EXT map is in flat format, use:
# https://rtd.igwn.org/projects/gwcelery/en/latest/_modules/gwcelery/tasks/external_skymaps.html#combine_skymaps_moc_flat

# %%
comb_skymap = combine_skymaps_moc_moc(skymap_gw, skymap_grb)
comb_skymap.write('combined_skymap.fits', overwrite=True)

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as pp
from matplotlib.colors import LogNorm
from matplotlib import cm
import ligo.skymap.plot
import ligo.skymap.io.fits
import numpy as np

gw_map, _ = ligo.skymap.io.fits.read_sky_map('Bilby.multiorder.fits', nest=True)
grb_map, _ = ligo.skymap.io.fits.read_sky_map('754189311_0_n_PROBMAP.fits', nest=True)
comb_map, _ = ligo.skymap.io.fits.read_sky_map('combined_skymap.fits', nest=True)

def plot_panel(ax, skymap, title, cmap):
    import ligo.skymap.postprocess.util
    cls = 100 * ligo.skymap.postprocess.util.find_greedy_credible_levels(skymap)
    vmax = np.percentile(skymap[~np.isnan(skymap)], 99.0)
    vmin = np.percentile(skymap[~np.isnan(skymap)], 10.0)
    vmin = max(vmax/1e3, vmin)
    skymap_plot = skymap.copy()
    skymap_plot[cls > 90] = np.nan
    skymap_plot[skymap_plot == 0] = np.nan
    ax.set_facecolor('none')
    ax.grid()
    ax.imshow_hpx((skymap_plot, 'ICRS'), nested=True,
                  cmap=cmap, norm=LogNorm(vmin=vmin, vmax=vmax), zorder=0)
    ax.contour_hpx((cls, 'ICRS'), nested=True, colors='black',
                   levels=(50, 90), zorder=1,
                   linestyles=['dashed', 'solid'], linewidths=0.5)
    ax.set_title(title)

fig = pp.figure(figsize=(10, 12), dpi=100)

ax1 = pp.subplot(3, 1, 1, projection='astro degrees mollweide')
ax2 = pp.subplot(3, 1, 2, projection='astro degrees mollweide')

ax3 = pp.subplot(3, 1, 3, projection='astro degrees mollweide')
plot_panel(ax1, gw_map, 'GW skymap', cm.Blues)
plot_panel(ax2, grb_map, 'GRB skymap', cm.Greens)
plot_panel(ax3, comb_map, 'Combined skymap', cm.Oranges)

pp.tight_layout()
pp.show()

# %% [markdown]
# Zoom on the peak of the EXT map

# %%
skymap, _ = ligo.skymap.io.fits.read_sky_map('combined_skymap.fits', nest = True) # NEST = True ensures that the order is rearranged properly, both for flat and multi-order maps

fig = pp.figure(figsize=(10, 12), dpi=200)
ax = pp.axes(projection='astro degrees zoom',
              center=f'52 d +70 d', radius='10 deg')

cls = 100 * ligo.skymap.postprocess.util.find_greedy_credible_levels(skymap)

vmax = np.percentile(skymap[~np.isnan(skymap)], 99.0)
vmin = np.percentile(skymap[~np.isnan(skymap)], 10.0)
vmin = max(vmax/1e3, vmin)

skymap[cls > 90] = np.nan
skymap[skymap == 0] = np.nan


ax.imshow_hpx((skymap, 'ICRS'), nested=True, cmap=cm.Oranges, norm=LogNorm(vmin=vmin, vmax=vmax), zorder=0)
ax.contour_hpx((cls, 'ICRS'), nested=True, colors='black', levels=(50, 90), zorder=1, linestyles=['dashed', 'solid'])

# %% [markdown]
# ## How likely is to have randomly the sky overlap we obtain?

# %%
import healpy as hp
import numpy as np
import matplotlib.pyplot as pp

random_overlaps = []
import ligo.skymap.plot
import ligo.skymap.io.fits
import numpy as np

gw_map, _ = ligo.skymap.io.fits.read_sky_map('Bilby.multiorder.fits', nest=True)
skymap_grb, _ = ligo.skymap.io.fits.read_sky_map('754189311_0_n_PROBMAP.fits', nest=True)

# Generate random rotation angles
n_rotations = 100
phis = np.random.uniform(0.0, 360.0, n_rotations)           # φ ~ U(0, 2π)
u = np.random.uniform(-1.0, 1.0, n_rotations)               # cosθ ~ U(-1, 1)
thetas = np.degrees(np.arccos(u))                           # θ = arccos(u)
psis = np.random.uniform(0.0, 360.0, n_rotations)           # ψ ~ U(0, 2π)

rotated_maps = np.array([
    hp.Rotator(rot=[phi, theta, psi], deg=True).rotate_map_pixel(gw_map)
    for phi, theta, psi in zip(phis, thetas, psis)
])

# %%
# Calculate overlaps for all rotated maps
skymap_grb, _ = ligo.skymap.io.fits.read_sky_map('754189311_0_n_PROBMAP.fits', nest=True)
random_overlaps = [np.log(search.skymap_overlap_integral(rotated_map, ext_skymap=skymap_grb)) 
                    for rotated_map in rotated_maps]

pp.hist(random_overlaps, bins=20, alpha=0.7, color='blue', edgecolor='black')
pp.axvline(np.log(sky_overlap), color='red', linestyle='dashed', linewidth=2, label='Actual Overlap')
pp.xlabel('Log Skymap Overlap Integral')
pp.ylabel('Frequency')
pp.yscale('log')
pp.title('Distribution of Skymap Overlap Integrals from Random Rotations')
pp.legend()

# %%
# number of random overlaps greater than or equal to the actual overlap
n_greater_equal = sum(1 for overlap in random_overlaps if overlap >= np.log(sky_overlap))
p_value = n_greater_equal / n_rotations
p_value
# Out:
# 0.14

# %% [markdown]
# ## Bonus: tiling the resulting joint map

# %%
def fibonacci_sphere(n_samples):
    """
    Generate uniformly distributed points on a sphere using Fibonacci lattice.
    This provides optimal uniform coverage - better than HEALPix for circle packing.
    
    Based on: "How to generate equidistributed points on the surface of a sphere"
    by Àlex Comas (2015) and Vogel's method.
    
    Parameters:
    -----------
    n_samples : int
        Number of points to generate
    
    Returns:
    --------
    ra, dec : arrays
        Right ascension and declination in degrees
    """
    golden_ratio = (1 + np.sqrt(5)) / 2
    
    # Generate indices
    i = np.arange(n_samples)
    
    # Latitude: uniform distribution in cos(theta) ensures equal-area spacing
    theta = np.arccos(1 - 2 * (i + 0.5) / n_samples)
    
    # Longitude: golden angle spiral
    phi = 2 * np.pi * i / golden_ratio
    
    # Convert to RA, Dec
    dec = 90 - np.rad2deg(theta)
    ra = np.rad2deg(phi) % 360
    
    return ra, dec


def optimize_circle_coverage(skymap, r_circle_deg, target_coverage=0.9):
    """
    Find optimal number of circles to cover target probability on skymap.
    Uses Fibonacci lattice for uniform initial distribution + greedy selection.
    OPTIMIZED: Pre-ranks circles by total probability, then uses greedy selection
    with coverage tracking.
    
    Key features:
    - Hexagonal-like packing: circles spaced 2r apart (only pairs touch, no triple overlap)
    - No double-counting: tracks covered pixels to compute only new probability added
    - FAST: Pre-sorted by probability, vectorized numpy operations
    
    Parameters:
    -----------
    r_circle_deg : float
        Circle radius in degrees
    target_coverage : float
        Target probability coverage (e.g., 0.9 for 90%)
    
    Returns:
    --------
    selected_circles : list of tuples
        (ra, dec, probability_added) for each selected circle
    """
    r_rad = np.deg2rad(r_circle_deg)
    
    # Estimate sphere area that can be covered by one circle (spherical cap area)
    cap_area = 2 * np.pi * (1 - np.cos(r_rad))  # steradians
    sphere_area = 4 * np.pi  # steradians
    
    # For hexagonal packing on a SPHERE, accounting for curvature:
    # Optimal spacing for hexagonal close packing of spherical caps:
    # d = 2 * arcsin(sqrt(3)/2 * sin(r))
    # For small angles: d ≈ sqrt(3) * r
    target_spacing_rad = 2 * np.arcsin(np.sqrt(3)/2 * np.sin(r_rad))
    
    # Each circle "owns" area in hexagonal tessellation
    # Voronoi cell area ≈ 2√3 r² for planar, adjusted for sphere
    packing_efficiency = 0.907  # hexagonal close packing efficiency
    n_circles_theoretical = int(np.ceil(sphere_area / (cap_area * packing_efficiency)))
    
    # Estimate number of Fibonacci points for target spacing
    points_per_steradian = 1 / (target_spacing_rad ** 2)
    n_candidates = int(sphere_area * points_per_steradian * 1.5)  # 50% extra for greedy selection
    
    print(f"Circle radius: {r_circle_deg}°")
    print(f"Spherical cap area: {np.rad2deg(np.rad2deg(cap_area)):.2f} deg²")
    print(f"Hexagonal packing spacing (spherical): {np.rad2deg(target_spacing_rad):.3f}°")
    print(f"  (≈ {np.rad2deg(target_spacing_rad)/r_circle_deg:.3f} × r, vs √3={np.sqrt(3):.3f} in planar case)")
    print(f"Theoretical circles for full coverage: {n_circles_theoretical}")
    print(f"Generating {n_candidates} candidate positions using Fibonacci lattice...")
    
    # Generate candidate centers using Fibonacci lattice
    ra_centers, dec_centers = fibonacci_sphere(n_candidates)
    
    # Prepare circle data with probability information
    nside = hp.npix2nside(len(skymap))
    circle_data = []
    
    print("Computing probability in each circle...")
    for ra_c, dec_c in zip(ra_centers, dec_centers):
        theta_c = np.radians(90 - dec_c)
        phi_c = np.radians(ra_c)
        xyz_c = hp.ang2vec(theta_c, phi_c)
        
        # Get pixels within the circle (as numpy array for faster operations)
        ipix_disc = np.array(hp.query_disc(nside, xyz_c, r_rad, nest=True), dtype=np.int32)
        
        # Total probability in this circle
        total_prob = np.nansum(skymap[ipix_disc])
        circle_data.append((ra_c, dec_c, ipix_disc, total_prob))
    
    # ============ OPTIMIZED GREEDY SELECTION (vectorized, not loops) ============
    print(f"Running greedy selection for {target_coverage:.0%} coverage...")
    print("(Each circle only counts probability from pixels not yet covered)\n")
    
    selected_circles = []
    covered_pixels = np.zeros(len(skymap), dtype=bool)  # Boolean mask instead of set
    cumulative_prob = 0.0
    
    iteration = 0
    max_iterations = len(circle_data)  # Safety limit
    
    while cumulative_prob < target_coverage and circle_data and iteration < max_iterations:
        iteration += 1
        
        # VECTORIZED: compute new probability for ALL circles at once
        # Convert covered_pixels to numpy for fast masking
        best_idx = -1
        best_new_prob = 0.0
        best_uncovered_mask = None
        
        for idx, (ra_c, dec_c, ipix_disc, _) in enumerate(circle_data):
            # Fast numpy masking: find pixels in circle that aren't covered
            uncovered_mask = ~covered_pixels[ipix_disc]
            
            # Sum only uncovered probabilities (no double-counting)
            new_prob = np.nansum(skymap[ipix_disc[uncovered_mask]])
            
            if new_prob > best_new_prob:
                best_new_prob = new_prob
                best_idx = idx
                best_uncovered_mask = uncovered_mask
        
        # If no circle adds new probability, stop
        if best_idx == -1 or best_new_prob == 0:
            break
        
        # Add best circle to selection
        ra_c, dec_c, ipix_disc, _ = circle_data[best_idx]
        selected_circles.append((ra_c, dec_c, best_new_prob))
        
        # Mark newly covered pixels (fast boolean indexing)
        covered_pixels[ipix_disc[best_uncovered_mask]] = True
        cumulative_prob += best_new_prob
        
        # Remove selected circle from candidates
        circle_data.pop(best_idx)
        
        # Progress update every 10 circles
        if len(selected_circles) % 10 == 0:
            avg_new_prob = cumulative_prob / len(selected_circles)
            print(f"  Iteration {iteration}: {len(selected_circles)} circles, "
                  f"coverage: {cumulative_prob:.2%}, avg new prob/circle: {avg_new_prob:.3%}")
    
    print(f"\n✓ Selected {len(selected_circles)} circles covering {cumulative_prob:.2%}")
    if len(selected_circles) > 0:
        print(f"  Average new probability per circle: {cumulative_prob/len(selected_circles):.3%}")
    print(f"  Total unique pixels covered: {np.sum(covered_pixels):,} (no double-counting)")
    
    return selected_circles


# Test with different circle sizes
r_circle = 23/2 / 60  # degrees
skymap, _ = ligo.skymap.io.fits.read_sky_map('combined_skymap.fits', nest = True) # NEST = True ensures that the order is rearranged properly, both for flat and multi-order maps
selected_circles = optimize_circle_coverage(skymap, r_circle, target_coverage=0.90)
# Out:
# Circle radius: 0.19166666666666668°
# Spherical cap area: 0.12 deg²
# Hexagonal packing spacing (spherical): 0.332°
#   (≈ 1.732 × r, vs √3=1.732 in planar case)
# Theoretical circles for full coverage: 394099
# Generating 561477 candidate positions using Fibonacci lattice...
# Computing probability in each circle and ranking...
# Top 5 circles by initial probability:
#   #1: RA=58.37°, Dec=69.61°, P=0.7994
#   #2: RA=57.68°, Dec=69.74°, P=0.7472
#   #3: RA=53.08°, Dec=66.59°, P=0.0073
#   #4: RA=53.51°, Dec=66.78°, P=0.0033
#   #5: RA=54.56°, Dec=65.55°, P=0.0027
#
# Running greedy selection for 90% coverage...
# (Each circle only counts probability from pixels not yet covered)
#
#   Circle 10: coverage 81.36%, avg new prob/circle: 8.136%
#   Circle 20: coverage 81.56%, avg new prob/circle: 4.078%
#   Circle 30: coverage 81.64%, avg new prob/circle: 2.721%
#   Circle 40: coverage 81.74%, avg new prob/circle: 2.043%
#   Circle 50: coverage 81.82%, avg new prob/circle: 1.636%
#   Circle 60: coverage 81.90%, avg new prob/circle: 1.365%
#   Circle 70: coverage 81.99%, avg new prob/circle: 1.171%
#   Circle 80: coverage 82.06%, avg new prob/circle: 1.026%
#   Circle 90: coverage 82.14%, avg new prob/circle: 0.913%
#   Circle 100: coverage 82.21%, avg new prob/circle: 0.822%
#   Circle 110: coverage 82.28%, avg new prob/circle: 0.748%
#   Circle 120: coverage 82.36%, avg new prob/circle: 0.686%
#   Circle 130: coverage 82.42%, avg new prob/circle: 0.634%
#   Circle 140: coverage 82.50%, avg new prob/circle: 0.589%
#   Circle 150: coverage 82.56%, avg new prob/circle: 0.550%
#   Circle 160: coverage 82.64%, avg new prob/circle: 0.516%
#   Circle 170: coverage 82.70%, avg new prob/circle: 0.486%
#   Circle 180: coverage 82.77%, avg new prob/circle: 0.460%
#   Circle 190: coverage 82.84%, avg new prob/circle: 0.436%
#   Circle 200: coverage 82.91%, avg new prob/circle: 0.415%
#   Circle 210: coverage 82.96%, avg new prob/circle: 0.395%
#   Circle 220: coverage 83.03%, avg new prob/circle: 0.377%
#   Circle 230: coverage 83.08%, avg new prob/circle: 0.361%
#   Circle 240: coverage 83.14%, avg new prob/circle: 0.346%
#   Circle 250: coverage 83.20%, avg new prob/circle: 0.333%
#   Circle 260: coverage 83.27%, avg new prob/circle: 0.320%
#   Circle 270: coverage 83.31%, avg new prob/circle: 0.309%
#   Circle 280: coverage 83.37%, avg new prob/circle: 0.298%
#   Circle 290: coverage 83.42%, avg new prob/circle: 0.288%
#   Circle 300: coverage 83.48%, avg new prob/circle: 0.278%
#   Circle 310: coverage 83.52%, avg new prob/circle: 0.269%
#   Circle 320: coverage 83.57%, avg new prob/circle: 0.261%
#   Circle 330: coverage 83.62%, avg new prob/circle: 0.253%
#   Circle 340: coverage 83.66%, avg new prob/circle: 0.246%
#   Circle 350: coverage 83.72%, avg new prob/circle: 0.239%
#   Circle 360: coverage 83.77%, avg new prob/circle: 0.233%
#   Circle 370: coverage 83.83%, avg new prob/circle: 0.227%
#   Circle 380: coverage 83.88%, avg new prob/circle: 0.221%
#   Circle 390: coverage 83.93%, avg new prob/circle: 0.215%
#   Circle 400: coverage 83.99%, avg new prob/circle: 0.210%
#   Circle 410: coverage 84.03%, avg new prob/circle: 0.205%
#   Circle 420: coverage 84.09%, avg new prob/circle: 0.200%
#   Circle 430: coverage 84.15%, avg new prob/circle: 0.196%
#   Circle 440: coverage 84.20%, avg new prob/circle: 0.191%
#   Circle 450: coverage 84.25%, avg new prob/circle: 0.187%
#   Circle 460: coverage 84.30%, avg new prob/circle: 0.183%
#   Circle 470: coverage 84.35%, avg new prob/circle: 0.179%
#   Circle 480: coverage 84.40%, avg new prob/circle: 0.176%
#   Circle 490: coverage 84.45%, avg new prob/circle: 0.172%
#   Circle 500: coverage 84.50%, avg new prob/circle: 0.169%
#   Circle 510: coverage 84.56%, avg new prob/circle: 0.166%
#   Circle 520: coverage 84.60%, avg new prob/circle: 0.163%
#   Circle 530: coverage 84.65%, avg new prob/circle: 0.160%
#   Circle 540: coverage 84.69%, avg new prob/circle: 0.157%
#   Circle 550: coverage 84.74%, avg new prob/circle: 0.154%
#   Circle 560: coverage 84.79%, avg new prob/circle: 0.151%
#   Circle 570: coverage 84.84%, avg new prob/circle: 0.149%
#   Circle 580: coverage 84.88%, avg new prob/circle: 0.146%
#   Circle 590: coverage 84.93%, avg new prob/circle: 0.144%
#   Circle 600: coverage 84.97%, avg new prob/circle: 0.142%
#   Circle 610: coverage 85.02%, avg new prob/circle: 0.139%
#   Circle 620: coverage 85.06%, avg new prob/circle: 0.137%
#   Circle 630: coverage 85.11%, avg new prob/circle: 0.135%
#   Circle 640: coverage 85.16%, avg new prob/circle: 0.133%
#   Circle 650: coverage 85.19%, avg new prob/circle: 0.131%
#   Circle 660: coverage 85.23%, avg new prob/circle: 0.129%
#   Circle 670: coverage 85.28%, avg new prob/circle: 0.127%
#   Circle 680: coverage 85.32%, avg new prob/circle: 0.125%
#   Circle 690: coverage 85.36%, avg new prob/circle: 0.124%
#   Circle 700: coverage 85.41%, avg new prob/circle: 0.122%
#   Circle 710: coverage 85.45%, avg new prob/circle: 0.120%
#   Circle 720: coverage 85.50%, avg new prob/circle: 0.119%
#   Circle 730: coverage 85.53%, avg new prob/circle: 0.117%
#   Circle 740: coverage 85.57%, avg new prob/circle: 0.116%
#   Circle 750: coverage 85.62%, avg new prob/circle: 0.114%
#   Circle 760: coverage 85.66%, avg new prob/circle: 0.113%
#   Circle 770: coverage 85.69%, avg new prob/circle: 0.111%
#   Circle 780: coverage 85.73%, avg new prob/circle: 0.110%
#   Circle 790: coverage 85.78%, avg new prob/circle: 0.109%
#   Circle 800: coverage 85.82%, avg new prob/circle: 0.107%
#   Circle 810: coverage 85.86%, avg new prob/circle: 0.106%
#   Circle 820: coverage 85.90%, avg new prob/circle: 0.105%
#   Circle 830: coverage 85.94%, avg new prob/circle: 0.104%
#   Circle 840: coverage 85.98%, avg new prob/circle: 0.102%
#   Circle 850: coverage 86.02%, avg new prob/circle: 0.101%
#   Circle 860: coverage 86.07%, avg new prob/circle: 0.100%
#   Circle 870: coverage 86.11%, avg new prob/circle: 0.099%
#   Circle 880: coverage 86.14%, avg new prob/circle: 0.098%
#   Circle 890: coverage 86.19%, avg new prob/circle: 0.097%
#   Circle 900: coverage 86.23%, avg new prob/circle: 0.096%
#   Circle 910: coverage 86.26%, avg new prob/circle: 0.095%
#   Circle 920: coverage 86.30%, avg new prob/circle: 0.094%
#   Circle 930: coverage 86.33%, avg new prob/circle: 0.093%
#   Circle 940: coverage 86.36%, avg new prob/circle: 0.092%
#   Circle 950: coverage 86.40%, avg new prob/circle: 0.091%
#   Circle 960: coverage 86.44%, avg new prob/circle: 0.090%
#   Circle 970: coverage 86.48%, avg new prob/circle: 0.089%
#   Circle 980: coverage 86.51%, avg new prob/circle: 0.088%
#   Circle 990: coverage 86.54%, avg new prob/circle: 0.087%
#   Circle 1000: coverage 86.57%, avg new prob/circle: 0.087%
#   Circle 1010: coverage 86.60%, avg new prob/circle: 0.086%
#   Circle 1020: coverage 86.64%, avg new prob/circle: 0.085%
#   Circle 1030: coverage 86.67%, avg new prob/circle: 0.084%
#   Circle 1040: coverage 86.71%, avg new prob/circle: 0.083%
#   Circle 1050: coverage 86.75%, avg new prob/circle: 0.083%
#   Circle 1060: coverage 86.78%, avg new prob/circle: 0.082%
#   Circle 1070: coverage 86.82%, avg new prob/circle: 0.081%
#   Circle 1080: coverage 86.85%, avg new prob/circle: 0.080%
#   Circle 1090: coverage 86.88%, avg new prob/circle: 0.080%
#   Circle 1100: coverage 86.91%, avg new prob/circle: 0.079%
#   Circle 1110: coverage 86.95%, avg new prob/circle: 0.078%
#   Circle 1120: coverage 86.98%, avg new prob/circle: 0.078%
#   Circle 1130: coverage 87.01%, avg new prob/circle: 0.077%
#   Circle 1140: coverage 87.04%, avg new prob/circle: 0.076%
#   Circle 1150: coverage 87.08%, avg new prob/circle: 0.076%
#   Circle 1160: coverage 87.11%, avg new prob/circle: 0.075%
#   Circle 1170: coverage 87.14%, avg new prob/circle: 0.074%
#   Circle 1180: coverage 87.17%, avg new prob/circle: 0.074%
#   Circle 1190: coverage 87.21%, avg new prob/circle: 0.073%
#   Circle 1200: coverage 87.24%, avg new prob/circle: 0.073%
#   Circle 1210: coverage 87.27%, avg new prob/circle: 0.072%
#   Circle 1220: coverage 87.29%, avg new prob/circle: 0.072%
#   Circle 1230: coverage 87.33%, avg new prob/circle: 0.071%
#   Circle 1240: coverage 87.36%, avg new prob/circle: 0.070%
#   Circle 1250: coverage 87.39%, avg new prob/circle: 0.070%
#   Circle 1260: coverage 87.42%, avg new prob/circle: 0.069%
#   Circle 1270: coverage 87.46%, avg new prob/circle: 0.069%
#   Circle 1280: coverage 87.48%, avg new prob/circle: 0.068%
#   Circle 1290: coverage 87.51%, avg new prob/circle: 0.068%
#   Circle 1300: coverage 87.54%, avg new prob/circle: 0.067%
#   Circle 1310: coverage 87.58%, avg new prob/circle: 0.067%
#   Circle 1320: coverage 87.60%, avg new prob/circle: 0.066%
#   Circle 1330: coverage 87.63%, avg new prob/circle: 0.066%
#   Circle 1340: coverage 87.67%, avg new prob/circle: 0.065%
#   Circle 1350: coverage 87.70%, avg new prob/circle: 0.065%
#   Circle 1360: coverage 87.73%, avg new prob/circle: 0.065%
#   Circle 1370: coverage 87.76%, avg new prob/circle: 0.064%
#   Circle 1380: coverage 87.79%, avg new prob/circle: 0.064%
#   Circle 1390: coverage 87.82%, avg new prob/circle: 0.063%
#   Circle 1400: coverage 87.84%, avg new prob/circle: 0.063%
#   Circle 1410: coverage 87.87%, avg new prob/circle: 0.062%
#   Circle 1420: coverage 87.89%, avg new prob/circle: 0.062%
#   Circle 1430: coverage 87.92%, avg new prob/circle: 0.061%
#   Circle 1440: coverage 87.95%, avg new prob/circle: 0.061%
#   Circle 1450: coverage 87.98%, avg new prob/circle: 0.061%
#   Circle 1460: coverage 88.00%, avg new prob/circle: 0.060%
#   Circle 1470: coverage 88.02%, avg new prob/circle: 0.060%
#   Circle 1480: coverage 88.05%, avg new prob/circle: 0.059%
#   Circle 1490: coverage 88.08%, avg new prob/circle: 0.059%
#   Circle 1500: coverage 88.11%, avg new prob/circle: 0.059%
#   Circle 1510: coverage 88.14%, avg new prob/circle: 0.058%
#   Circle 1520: coverage 88.16%, avg new prob/circle: 0.058%
#   Circle 1530: coverage 88.19%, avg new prob/circle: 0.058%
#   Circle 1540: coverage 88.22%, avg new prob/circle: 0.057%
#   Circle 1550: coverage 88.24%, avg new prob/circle: 0.057%
#   Circle 1560: coverage 88.26%, avg new prob/circle: 0.057%
#   Circle 1570: coverage 88.29%, avg new prob/circle: 0.056%
#   Circle 1580: coverage 88.31%, avg new prob/circle: 0.056%
#   Circle 1590: coverage 88.34%, avg new prob/circle: 0.056%
#   Circle 1600: coverage 88.36%, avg new prob/circle: 0.055%
#   Circle 1610: coverage 88.39%, avg new prob/circle: 0.055%
#   Circle 1620: coverage 88.41%, avg new prob/circle: 0.055%
#   Circle 1630: coverage 88.43%, avg new prob/circle: 0.054%
#   Circle 1640: coverage 88.46%, avg new prob/circle: 0.054%
#   Circle 1650: coverage 88.49%, avg new prob/circle: 0.054%
#   Circle 1660: coverage 88.51%, avg new prob/circle: 0.053%
#   Circle 1670: coverage 88.54%, avg new prob/circle: 0.053%
#   Circle 1680: coverage 88.56%, avg new prob/circle: 0.053%
#   Circle 1690: coverage 88.59%, avg new prob/circle: 0.052%
#   Circle 1700: coverage 88.61%, avg new prob/circle: 0.052%
#   Circle 1710: coverage 88.63%, avg new prob/circle: 0.052%
#   Circle 1720: coverage 88.66%, avg new prob/circle: 0.052%
#   Circle 1730: coverage 88.69%, avg new prob/circle: 0.051%
#   Circle 1740: coverage 88.71%, avg new prob/circle: 0.051%
#   Circle 1750: coverage 88.73%, avg new prob/circle: 0.051%
#   Circle 1760: coverage 88.75%, avg new prob/circle: 0.050%
#   Circle 1770: coverage 88.77%, avg new prob/circle: 0.050%
#   Circle 1780: coverage 88.80%, avg new prob/circle: 0.050%
#   Circle 1790: coverage 88.82%, avg new prob/circle: 0.050%
#   Circle 1800: coverage 88.84%, avg new prob/circle: 0.049%
#   Circle 1810: coverage 88.86%, avg new prob/circle: 0.049%
#   Circle 1820: coverage 88.89%, avg new prob/circle: 0.049%
#   Circle 1830: coverage 88.91%, avg new prob/circle: 0.049%
#   Circle 1840: coverage 88.93%, avg new prob/circle: 0.048%
#   Circle 1850: coverage 88.95%, avg new prob/circle: 0.048%
#   Circle 1860: coverage 88.98%, avg new prob/circle: 0.048%
#   Circle 1870: coverage 89.00%, avg new prob/circle: 0.048%
#   Circle 1880: coverage 89.02%, avg new prob/circle: 0.047%
#   Circle 1890: coverage 89.04%, avg new prob/circle: 0.047%
#   Circle 1900: coverage 89.06%, avg new prob/circle: 0.047%
#   Circle 1910: coverage 89.08%, avg new prob/circle: 0.047%
#   Circle 1920: coverage 89.10%, avg new prob/circle: 0.046%
#   Circle 1930: coverage 89.12%, avg new prob/circle: 0.046%
#   Circle 1940: coverage 89.14%, avg new prob/circle: 0.046%
#   Circle 1950: coverage 89.16%, avg new prob/circle: 0.046%
#   Circle 1960: coverage 89.19%, avg new prob/circle: 0.046%
#   Circle 1970: coverage 89.21%, avg new prob/circle: 0.045%
#   Circle 1980: coverage 89.23%, avg new prob/circle: 0.045%
#   Circle 1990: coverage 89.25%, avg new prob/circle: 0.045%
#   Circle 2000: coverage 89.27%, avg new prob/circle: 0.045%
#   Circle 2010: coverage 89.29%, avg new prob/circle: 0.044%
#   Circle 2020: coverage 89.32%, avg new prob/circle: 0.044%
#   Circle 2030: coverage 89.34%, avg new prob/circle: 0.044%
#   Circle 2040: coverage 89.36%, avg new prob/circle: 0.044%
#   Circle 2050: coverage 89.38%, avg new prob/circle: 0.044%
#   Circle 2060: coverage 89.40%, avg new prob/circle: 0.043%
#   Circle 2070: coverage 89.43%, avg new prob/circle: 0.043%
#   Circle 2080: coverage 89.45%, avg new prob/circle: 0.043%
#   Circle 2090: coverage 89.47%, avg new prob/circle: 0.043%
#   Circle 2100: coverage 89.49%, avg new prob/circle: 0.043%
#   Circle 2110: coverage 89.51%, avg new prob/circle: 0.042%
#   Circle 2120: coverage 89.53%, avg new prob/circle: 0.042%
#   Circle 2130: coverage 89.55%, avg new prob/circle: 0.042%
#   Circle 2140: coverage 89.57%, avg new prob/circle: 0.042%
#   Circle 2150: coverage 89.60%, avg new prob/circle: 0.042%
#   Circle 2160: coverage 89.62%, avg new prob/circle: 0.041%
#   Circle 2170: coverage 89.64%, avg new prob/circle: 0.041%
#   Circle 2180: coverage 89.66%, avg new prob/circle: 0.041%
#   Circle 2190: coverage 89.68%, avg new prob/circle: 0.041%
#   Circle 2200: coverage 89.70%, avg new prob/circle: 0.041%
#   Circle 2210: coverage 89.72%, avg new prob/circle: 0.041%
#   Circle 2220: coverage 89.73%, avg new prob/circle: 0.040%
#   Circle 2230: coverage 89.75%, avg new prob/circle: 0.040%
#   Circle 2240: coverage 89.77%, avg new prob/circle: 0.040%
#   Circle 2250: coverage 89.79%, avg new prob/circle: 0.040%
#   Circle 2260: coverage 89.81%, avg new prob/circle: 0.040%
#   Circle 2270: coverage 89.83%, avg new prob/circle: 0.040%
#   Circle 2280: coverage 89.84%, avg new prob/circle: 0.039%
#   Circle 2290: coverage 89.86%, avg new prob/circle: 0.039%
#   Circle 2300: coverage 89.88%, avg new prob/circle: 0.039%
#   Circle 2310: coverage 89.90%, avg new prob/circle: 0.039%
#   Circle 2320: coverage 89.92%, avg new prob/circle: 0.039%
#   Circle 2330: coverage 89.93%, avg new prob/circle: 0.039%
#   Circle 2340: coverage 89.95%, avg new prob/circle: 0.038%
#   Circle 2350: coverage 89.97%, avg new prob/circle: 0.038%
#   Circle 2360: coverage 89.99%, avg new prob/circle: 0.038%
#
# ✓ Selected 2364 circles covering 90.00%
#   Average new probability per circle: 0.038%
#   Total unique pixels covered: 55,184 (no double-counting)

# %%
# Visualize the selected circles on the skymap
import matplotlib.pyplot as plt
import ligo.skymap.postprocess.util
from astropy import units as u

cls = 100 * ligo.skymap.postprocess.util.find_greedy_credible_levels(skymap)

def plot_spherical_cap(ax, center_lon_deg, center_lat_deg, radius_deg,
                       npoints=720, fill=True, facecolor='none', edgecolor='red',
                       alpha=0.3, linewidth=0.8, zorder=5):
    """
    Plot a spherical cap (sphere ∩ cone) on an axes that accepts transform=ax.get_transform('icrs').
    center_lon_deg, center_lat_deg: degrees (RA/longitude, Dec/latitude in ICRS)
    radius_deg: angular radius of the cap in degrees
    npoints: number of points to sample boundary (higher -> smoother)
    
    Handles circles that cross the RA=0/360 boundary by splitting them into multiple segments.
    """
    # center as SkyCoord and radial positions around it
    center = SkyCoord(center_lon_deg * u.deg, center_lat_deg * u.deg, frame='icrs')
    pos_angles = np.linspace(0, 360, npoints) * u.deg
    boundary = center.directional_offset_by(pos_angles, radius_deg * u.deg)

    # Get RA in [0, 360) range
    ra = boundary.ra.deg
    dec = boundary.dec.deg

    # Detect large jumps in RA (>180 deg) indicating boundary crossing
    ra_diff = np.diff(ra)
    jumps = np.abs(ra_diff) > 180
    split_idx = np.where(jumps)[0]
    
    # Split into continuous segments
    segments = []
    start = 0
    for idx in split_idx:
        segments.append((ra[start:idx + 1], dec[start:idx + 1]))
        start = idx + 1
    segments.append((ra[start:], dec[start:]))

    # Plot each continuous segment
    transform = ax.get_transform('icrs')

    for seg_ra, seg_dec in segments:
        if len(seg_ra) < 2:
            continue
        if fill and facecolor != 'none':
            ax.fill(seg_ra, seg_dec, transform=transform,
                    facecolor=facecolor, edgecolor='none', alpha=alpha, zorder=zorder)
        # Always draw edge so the cap boundary is visible
        ax.plot(seg_ra, seg_dec, transform=transform, color=edgecolor,
                linewidth=linewidth, alpha=alpha, zorder=zorder + 1)
        
        # plot rank inside the cap
        


fig = plt.figure(figsize=(14, 8), dpi=300)
fig.patch.set_visible(False)
ax = pp.axes(projection='astro degrees zoom',
              center=f'52 d +70 d', radius='10 deg')
ax.set_facecolor('none')
ax.grid()

# Plot skymap
ax.imshow_hpx((skymap, 'ICRS'), nested=True, cmap='Blues', alpha=0.6)
ax.contour_hpx((cls, 'ICRS'), nested=True, colors='black',
               levels=(50, 90), zorder=1, linestyles=['dashed', 'solid'],
               linewidths=0.7)

# Plot selected circles as spherical caps
from astropy.coordinates import SkyCoord
print(f"Plotting {len(selected_circles)} optimized circles...")
rank = 1
for ra_c, dec_c, prob in selected_circles:
    plot_spherical_cap(ax, center_lon_deg=ra_c, center_lat_deg=dec_c, 
                       radius_deg=r_circle,
                       npoints=360, fill=False, facecolor='none', 
                       edgecolor='red', alpha=1, linewidth=1)

    # ax.text(ra_c, dec_c, str(rank), color='black', fontsize=8,
    #         ha='center', va='center', zorder=10, transform=ax.get_transform('icrs'))
    rank += 1


plt.tight_layout()
plt.show()
# Out:
# Plotting 2364 optimized circles...
