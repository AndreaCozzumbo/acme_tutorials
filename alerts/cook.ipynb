# %% [markdown]
# # Let's cook

# %% [markdown]
# Now it's your turn. We can now mix all together. Build a kafka listener that checks for new GW alerts, prints some info and process the skymap. Post all final results on the alert channel you prefer (Slack, mail,...). To test the listener, do a trial on S251112cm, check GCN circulars, choose a random AT* candidate from EM searches, extract RA and Dec, compute the at which contour level in the GW map is located and post value and map plot on the alert channel.

# %%
# Put your code here and remember to run either locally or on colab to have kafka wokring
